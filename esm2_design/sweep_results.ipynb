# %% [markdown]
# # FP architecture sweeps - results
#
# Each section reads its checkpoints directly. Label = `BACKBONE (depth) - pooling` (`None` = depth-0 pool-only baseline). Color = pooling, marker = backbone.
#
# Per task: leaderboard table, val-MAE barplot (embedding-NN k-sweep null models pinned at the top, outside the ranking), a val-vs-test scatter, and pred-vs-truth scatters for the top-3 configs on the validation set (MAE + R$^2$ in each corner).

# %%
# Shared loaders + plotters. Each sweep is read straight from its checkpoints.
import glob, os
import numpy as np, pandas as pd, torch
try:
    import arcadia_pycolor as apc; apc.mpl.setup(); HAVE_APC = True
except Exception:
    HAVE_APC = False
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

FS = 12
plt.rcParams.update({"font.size": FS, "axes.titlesize": FS, "axes.labelsize": FS,
                     "xtick.labelsize": FS, "ytick.labelsize": FS, "legend.fontsize": FS})

BB = {"cnn": "CNN", "transformer": "TF", "mlp": "None"}
POOL_C = {"mean": "#9a9a9a", "max": "#2b6c8f", "concat": "#f6a200", "concatstd": "#c5474b",
          "attn": "#3b8a6e", "null": "#111111"}
ARCH_M = {"mlp": "o", "cnn": "s", "transformer": "^"}
POOL_ORDER = ["mean", "max", "concat", "concatstd", "attn"]

def load_sweep(out_dir):
    recs = []
    for p in glob.glob(f"{out_dir}/*.pt"):
        ck = torch.load(p, map_location="cpu", weights_only=False)
        r = dict(arch=ck["arch"], pool=ck["pool"], depth=ck.get("depth"), seed=ck["seed"],
                 val_mae=ck["val_mae"], test_mae=ck["test_mae"],
                 label=f"{BB[ck['arch']]} ({ck.get('depth')}) - {ck['pool']}")
        if "val_ex" in ck:
            r["val_ex"] = ck["val_ex"]; r["val_em"] = ck["val_em"]
        recs.append(r)
    if not recs:                                                # no .pt weights -> fall back to the sweep's results.csv
        csv_path = os.path.join(out_dir, "results.csv")
        if os.path.exists(csv_path):
            s = pd.read_csv(csv_path)
            vm = "val_mae_mean" if "val_mae_mean" in s else "val_mae"        # per-role sweeps use *_mean/_std
            tm = "test_mae_mean" if "test_mae_mean" in s else "test_mae"     # single-seed scalar sweeps: bare cols
            out = pd.DataFrame({
                "label": [f"{BB[a]} ({d}) - {po}" for a, po, d in zip(s["arch"], s["pool"], s["depth"])],
                "arch": s["arch"], "pool": s["pool"], "depth": s["depth"],
                "n_seeds": s["n_seeds"] if "n_seeds" in s else 1,
                "val_mae": s[vm], "val_std": s.get("val_mae_std", 0.0),
                "test_mae": s[tm], "test_std": s.get("test_mae_std", 0.0)})
            print(f"(no .pt in {out_dir}; read leaderboard from results.csv — null baseline & pred-vs-truth need checkpoints)")
            return out.sort_values("val_mae").reset_index(drop=True)
        print(f"(no checkpoints or results.csv in {out_dir} yet)"); return None
    df = pd.DataFrame(recs)
    aggd = {"n_seeds": ("seed", "nunique"), "val_mae": ("val_mae", "mean"), "val_std": ("val_mae", "std"),
            "test_mae": ("test_mae", "mean"), "test_std": ("test_mae", "std")}
    if "val_ex" in df:
        aggd.update(val_ex=("val_ex", "mean"), val_em=("val_em", "mean"))
    agg = df.groupby(["label", "arch", "pool", "depth"]).agg(**aggd).reset_index()
    agg[["val_std", "test_std"]] = agg[["val_std", "test_std"]].fillna(0.0)
    return agg.sort_values("val_mae").reset_index(drop=True)

def show_table(agg):
    if agg is None: return "no checkpoints yet"
    cols = ["label", "arch", "pool", "depth", "n_seeds", "val_mae", "val_std", "test_mae", "test_std"]
    if "val_ex" in agg: cols += ["val_ex", "val_em"]
    return agg[cols].round(3)

def plot_bar(agg, unit, title, nulls=None):
    if agg is None: print("no data"); return
    cfg = agg[["label", "pool", "val_mae", "val_std"]].sort_values("val_mae", ascending=False).reset_index(drop=True)
    yc = np.arange(len(cfg))
    gap = 1.0
    n_null = len(nulls) if nulls else 0
    total = len(cfg) + (n_null + gap if n_null else 0)
    fig, ax = plt.subplots(figsize=(8.5, max(4.5, 0.2 * total)))
    _xerr = cfg["val_std"].to_numpy()
    _show_err = bool(np.nanmax(_xerr) > 0)                       # single-seed sweeps have std 0 -> no error bars/caps
    ax.barh(yc, cfg["val_mae"], xerr=(_xerr if _show_err else None), capsize=(2 if _show_err else 0),
            edgecolor="black", linewidth=0.3, color=[POOL_C.get(p, "#333") for p in cfg["pool"]])
    yticks, ylabels = list(yc), list(cfg["label"])
    if nulls:                                                    # null models pinned ABOVE the ranking
        items = list(nulls.items())
        yn = np.arange(n_null) + len(cfg) + gap
        ax.barh(yn, [v for _, v in items], color=POOL_C["null"], edgecolor="black", linewidth=0.3)
        ax.axhline(len(cfg) - 0.5 + gap / 2, ls=":", color="0.5", lw=1)
        yticks += list(yn); ylabels += [k for k, _ in items]
    ax.set_yticks(yticks); ax.set_yticklabels(ylabels, fontsize=FS)
    ax.set_xlabel(f"validation MAE ({unit})"); ax.set_title(title)
    handles = [Patch(color=POOL_C[p], label=p) for p in POOL_ORDER]
    if nulls: handles.append(Patch(color=POOL_C["null"], label="NN null"))
    ax.legend(handles=handles, title="pooling", fontsize=FS, title_fontsize=FS)
    ax.tick_params(labelsize=FS); ax.margins(y=0.01); plt.tight_layout(); plt.show()

def _legends(ax):
    ah = [Line2D([], [], marker=m, color="w", markerfacecolor="gray", markeredgecolor="k",
                 markersize=10, label=BB[a]) for a, m in ARCH_M.items()]
    l1 = ax.legend(handles=ah, title="backbone", fontsize=FS, title_fontsize=FS, loc="upper left"); ax.add_artist(l1)
    ax.legend(handles=[Patch(color=POOL_C[p], label=p) for p in POOL_ORDER],
              title="pooling", fontsize=FS, title_fontsize=FS, loc="lower right")

def plot_scatter(agg, unit, per_peak=False):
    if agg is None: print("no data"); return
    n = 2 if (per_peak and "val_ex" in agg) else 1
    fig, ax = plt.subplots(1, n, figsize=(6.5 * n, 5.8)); ax = np.atleast_1d(ax)
    for arch, m in ARCH_M.items():
        s = agg[agg.arch == arch]
        ax[0].scatter(s["val_mae"], s["test_mae"], marker=m, s=75, edgecolor="black", linewidth=0.4,
                      c=[POOL_C.get(p) for p in s["pool"]])
    lo, hi = agg[["val_mae", "test_mae"]].values.min(), agg[["val_mae", "test_mae"]].values.max()
    pad = 0.05 * (hi - lo + 1e-9); lim = [lo - pad, hi + pad]
    ax[0].plot(lim, lim, "k--", lw=1)
    b = agg.iloc[0]
    ax[0].annotate(b["label"], (b["val_mae"], b["test_mae"]), fontsize=FS, xytext=(5, 5), textcoords="offset points")
    ax[0].set_xlabel(f"val MAE ({unit})"); ax[0].set_ylabel(f"test MAE ({unit})")
    ax[0].set_title("val vs test  (marker = backbone, color = pooling)"); _legends(ax[0])
    if n == 2:
        for arch, m in ARCH_M.items():
            s = agg[agg.arch == arch]
            ax[1].scatter(s["val_ex"], s["val_em"], marker=m, s=75, edgecolor="black", linewidth=0.4,
                          c=[POOL_C.get(p) for p in s["pool"]])
        l2 = [min(agg.val_ex.min(), agg.val_em.min()) - 1, max(agg.val_ex.max(), agg.val_em.max()) + 1]
        ax[1].plot(l2, l2, "k--", lw=1)
        ax[1].set_xlabel("ex_max val MAE (nm)"); ax[1].set_ylabel("em_max val MAE (nm)")
        ax[1].set_title("per-peak difficulty (below y=x: em easier than ex)")
    plt.tight_layout(); plt.show()
# Out:
# Warning: The fonts were not found. The default matplotlib fonts will be used instead. To install the fonts, visit https://fonts.google.com/specimen/Atkinson+Hyperlegible+Next and https://fonts.google.com/specimen/Atkinson+Hyperlegible+Mono

# %%
# Prediction + baseline machinery: reuse the sweep modules to load each task's embeddings/split,
# run checkpoints on the validation set, and compute an embedding-NN k-sweep null model.
import sys as _sys
_sys.path.insert(0, os.path.abspath("../scalar_design"))  # sweep_scalar.py moved to the scalar_design/ sibling
import peak_models as pm, sweep_peak_oracle as swp, sweep_scalar as sws
from sklearn.neighbors import NearestNeighbors
dev = swp.device()
_DATA = {}
K_SWEEP = [1, 3, 5, 10, 20]

# peak now has two role-specific sweeps: surrogate (ESM-2 + surrogate split) and oracle
# (ProstT5 + oracle split). Each loads its own embedding cache + split via sweep_peak_oracle.
_PEAK_ROLE = {"peak_surrogate": "surrogate", "peak_oracle": "oracle"}

def get_data(task):
    if task not in _DATA:
        if task in _PEAK_ROLE:
            _DATA[task] = (swp.load_data(_PEAK_ROLE[task], dev), 2)
        else:
            _DATA[task] = (sws.load_data(task, dev), 1)
    return _DATA[task]

def truth(D, task):
    return D["Pk"].cpu().numpy() if task.startswith("peak") else D["y"]

def raw_label(r): return f"{r['arch']}-{r['pool']}-d{r['depth']}"

def predict(ckpt, D, idx, out):
    base, ck = pm.load_model(ckpt, dev, out=out)
    net = pm.wrap(base, ck["mean"], ck["std"], dev); net.eval()
    ps = []
    with torch.no_grad():
        for i in range(0, len(idx), 64):
            b = idx[i:i + 64]
            mk = (D["ar"].unsqueeze(0) < torch.tensor(D["Ls"][b]).unsqueeze(1)).to(dev)
            ps.append(net(D["Ht"][b].float().to(dev), mk).cpu().numpy())
    P = np.concatenate(ps)
    return P if out == 2 else P.ravel()

def pooled_embed(D):
    return np.stack([D["Ht"][i, :int(D["Ls"][i])].float().numpy().mean(0)
                     for i in range(D["N"])]).astype(np.float32)

def nn_predict(X, y, tr, va, k):
    nn = NearestNeighbors(n_neighbors=k, metric="cosine").fit(X[tr])
    idxs = nn.kneighbors(X[va], return_distance=False)
    return y[tr][idxs].mean(axis=1)

def r2(p, t): return 1.0 - np.sum((p - t) ** 2) / np.sum((t - t.mean()) ** 2)

def embed_nulls(task, ks=K_SWEEP):
    try:
        (D, out) = get_data(task)                               # needs the per-residue embedding cache
    except FileNotFoundError:
        print(f"(skipping NN null for {task}: embedding cache not built here)"); return None
    X = pooled_embed(D); y = truth(D, task); T = y[D["va"]]
    return {f"NN k={k}": float(np.abs(nn_predict(X, y, D["tr"], D["va"], k) - T).mean()) for k in ks}

def pred_vs_truth(task, agg, out_dir, split="va"):
    if agg is None: print("no data"); return
    if not glob.glob(os.path.join(out_dir, "*_s0.pt")):        # need per-config checkpoints to run predictions
        print(f"(skipping pred-vs-truth for {task}: no checkpoints in {out_dir})"); return
    try:
        (D, out) = get_data(task)                              # needs the per-residue embedding cache
    except FileNotFoundError:
        print(f"(skipping pred-vs-truth for {task}: embedding cache not built here)"); return
    y = truth(D, task); idx = D[split]
    split_name = {"va": "validation", "te": "test", "tr": "train"}.get(split, split)
    top3 = agg.head(3)
    cols = ["ex_max (nm)", "em_max (nm)"] if task.startswith("peak") else \
           [{"brightness": "log-brightness", "pka": "pKa (pH)"}[task]]
    nrow, ncol = (3, 2) if task.startswith("peak") else (1, 3)
    fig, axes = plt.subplots(nrow, ncol, figsize=(4.8 * ncol, 4.6 * nrow)); axes = np.atleast_2d(axes)
    for i, (_, r) in enumerate(top3.iterrows()):
        P = predict(os.path.join(out_dir, f"{raw_label(r)}_s0.pt"), D, idx, out)
        for j, cname in enumerate(cols):
            ax = axes[i, j] if task.startswith("peak") else axes[0, i]
            p = P[:, j] if task.startswith("peak") else P
            t = y[idx][:, j] if task.startswith("peak") else y[idx]
            lim = [min(p.min(), t.min()), max(p.max(), t.max())]
            ax.plot(lim, lim, "k--", lw=1)
            ax.scatter(t, p, s=20, alpha=0.7, color=POOL_C.get(r["pool"], "#333"), edgecolor="k", linewidth=0.3)
            ax.text(0.96, 0.04, f"MAE={np.abs(p - t).mean():.2f}\nR$^2$={r2(p, t):.2f}",
                    transform=ax.transAxes, ha="right", va="bottom", fontsize=FS,
                    bbox=dict(boxstyle="round", fc="white", ec="0.7", alpha=0.85))
            ax.set_xlabel(f"true {cname}"); ax.set_ylabel(f"predicted {cname}")
            ax.set_title(r["label"], fontsize=FS); ax.set_box_aspect(1)
    plt.suptitle(f"{task}: top-3 configs, predictions on {split_name} set", y=1.005, fontsize=FS)
    plt.tight_layout(); plt.show()

# %% [markdown]
# ## Peak - surrogate model (ESM-2 embedding, surrogate-specific split)

# %%
peak_surr = load_sweep("trained_models/surrogate_sweep")
show_table(peak_surr)
# Out:
#                    label         arch       pool  depth  n_seeds  val_mae  \
# 0          CNN (1) - max          cnn        max      1        1   13.809
# 1    CNN (1) - concatstd          cnn  concatstd      1        1   13.881
# 2       CNN (3) - concat          cnn     concat      3        1   14.082
# 3          CNN (2) - max          cnn        max      2        1   14.625
# 4       CNN (1) - concat          cnn     concat      1        1   15.019
# 5     TF (1) - concatstd  transformer  concatstd      1        1   15.125
# 6           TF (1) - max  transformer        max      1        1   15.307
# 7     TF (2) - concatstd  transformer  concatstd      2        1   15.815
# 8        TF (2) - concat  transformer     concat      2        1   15.900
# 9    CNN (2) - concatstd          cnn  concatstd      2        1   15.981
# 10      CNN (4) - concat          cnn     concat      4        1   16.164
# 11        CNN (1) - attn          cnn       attn      1        1   16.213
# 12      CNN (2) - concat          cnn     concat      2        1   16.302
# 13          TF (2) - max  transformer        max      2        1   16.763
# 14       TF (1) - concat  transformer     concat      1        1   17.279
# 15         TF (1) - attn  transformer       attn      1        1   17.765
# 16   CNN (3) - concatstd          cnn  concatstd      3        1   18.484
# 17         TF (3) - mean  transformer       mean      3        1   18.499
# 18         TF (2) - mean  transformer       mean      2        1   18.611
# 19        CNN (3) - mean          cnn       mean      3        1   18.752
# 20       None (0) - attn          mlp       attn      0        1   18.879
# 21   CNN (4) - concatstd          cnn  concatstd      4        1   18.983
# 22        CNN (4) - attn          cnn       attn      4        1   19.615
# 23        CNN (3) - attn          cnn       attn      3        1   19.660
# 24         TF (2) - attn  transformer       attn      2        1   20.304
# 25        CNN (2) - attn          cnn       attn      2        1   20.309
# 26         CNN (3) - max          cnn        max      3        1   20.467
# 27        CNN (2) - mean          cnn       mean      2        1   20.591
# 28         CNN (4) - max          cnn        max      4        1   21.161
# 29        CNN (1) - mean          cnn       mean      1        1   21.186
# 30        CNN (4) - mean          cnn       mean      4        1   22.037
# 31         TF (1) - mean  transformer       mean      1        1   22.252
# 32    TF (3) - concatstd  transformer  concatstd      3        1   22.915
# 33          TF (3) - max  transformer        max      3        1   22.937
# 34         TF (3) - attn  transformer       attn      3        1   23.322
# 35         TF (4) - mean  transformer       mean      4        1   23.571
# 36       TF (4) - concat  transformer     concat      4        1   23.604
# 37     None (0) - concat          mlp     concat      0        1   23.650
# 38       None (0) - mean          mlp       mean      0        1   23.921
# 39  None (0) - concatstd          mlp  concatstd      0        1   24.203
# 40    TF (4) - concatstd  transformer  concatstd      4        1   24.578
# 41        None (0) - max          mlp        max      0        1   24.578
# 42         TF (4) - attn  transformer       attn      4        1   24.778
# 43          TF (4) - max  transformer        max      4        1   28.168
# 44       TF (3) - concat  transformer     concat      3        1   31.153
#
#     val_std  test_mae  test_std  val_ex  val_em
# 0       0.0    14.403       0.0  17.089  10.529
# 1       0.0    14.215       0.0  17.244  10.518
# 2       0.0    14.757       0.0  17.854  10.311
# 3       0.0    15.877       0.0  17.868  11.382
# 4       0.0    15.601       0.0  17.763  12.275
# 5       0.0    17.810       0.0  18.278  11.972
# 6       0.0    16.440       0.0  18.578  12.035
# 7       0.0    17.120       0.0  19.216  12.414
# 8       0.0    18.465       0.0  19.137  12.664
# 9       0.0    16.925       0.0  20.070  11.892
# 10      0.0    15.832       0.0  19.003  13.324
# 11      0.0    18.074       0.0  19.734  12.692
# 12      0.0    15.762       0.0  20.489  12.114
# 13      0.0    17.952       0.0  20.217  13.308
# 14      0.0    18.278       0.0  20.267  14.291
# 15      0.0    21.012       0.0  21.496  14.035
# 16      0.0    20.405       0.0  21.366  15.602
# 17      0.0    18.948       0.0  22.254  14.743
# 18      0.0    19.401       0.0  21.277  15.945
# 19      0.0    20.816       0.0  22.381  15.123
# 20      0.0    20.525       0.0  22.146  15.612
# 21      0.0    21.182       0.0  21.429  16.536
# 22      0.0    22.913       0.0  23.143  16.087
# 23      0.0    23.037       0.0  24.172  15.149
# 24      0.0    23.978       0.0  23.973  16.635
# 25      0.0    23.862       0.0  24.286  16.332
# 26      0.0    20.967       0.0  25.024  15.910
# 27      0.0    25.056       0.0  24.314  16.868
# 28      0.0    25.114       0.0  25.825  16.497
# 29      0.0    25.435       0.0  25.307  17.066
# 30      0.0    25.009       0.0  26.446  17.628
# 31      0.0    28.458       0.0  25.903  18.601
# 32      0.0    29.560       0.0  27.537  18.293
# 33      0.0    29.750       0.0  28.521  17.353
# 34      0.0    27.321       0.0  28.502  18.142
# 35      0.0    28.274       0.0  27.722  19.420
# 36      0.0    28.534       0.0  28.555  18.653
# 37      0.0    27.684       0.0  28.164  19.136
# 38      0.0    28.151       0.0  28.379  19.464
# 39      0.0    27.853       0.0  28.350  20.056
# 40      0.0    32.276       0.0  29.921  19.234
# 41      0.0    27.756       0.0  28.974  20.181
# 42      0.0    31.456       0.0  28.692  20.864
# 43      0.0    32.270       0.0  34.333  22.003
# 44      0.0    35.379       0.0  38.969  23.338

# %%
plot_bar(peak_surr, "nm", "Peak surrogate sweep (ESM-2) - val MAE", nulls=embed_nulls("peak_surrogate"))
plot_bar(peak_surr.iloc[0:5], "nm", "Peak surrogate sweep (ESM-2) - top 5", nulls=embed_nulls("peak_surrogate"))

# %%
plot_scatter(peak_surr, "nm", per_peak=True)

# %%
pred_vs_truth("peak_surrogate", peak_surr, "trained_models/surrogate_sweep")

# %%
pred_vs_truth("peak_surrogate", peak_surr, "trained_models/surrogate_sweep", split="te")

# %% [markdown]
# ## Peak - oracle model (ProstT5 embedding, oracle-specific split)

# %%
peak_orac = load_sweep("trained_models/oracle_sweep")
show_table(peak_orac)
# Out:
#                    label         arch       pool  depth  n_seeds  val_mae  \
# 0          CNN (2) - max          cnn        max      2        1   13.725
# 1           TF (1) - max  transformer        max      1        1   14.383
# 2          CNN (4) - max          cnn        max      4        1   14.690
# 3          CNN (3) - max          cnn        max      3        1   14.852
# 4       CNN (2) - concat          cnn     concat      2        1   15.150
# 5       CNN (3) - concat          cnn     concat      3        1   15.265
# 6    CNN (1) - concatstd          cnn  concatstd      1        1   15.293
# 7     TF (1) - concatstd  transformer  concatstd      1        1   15.391
# 8         CNN (2) - attn          cnn       attn      2        1   15.573
# 9        TF (2) - concat  transformer     concat      2        1   15.602
# 10       TF (3) - concat  transformer     concat      3        1   15.650
# 11        CNN (3) - mean          cnn       mean      3        1   15.656
# 12   CNN (2) - concatstd          cnn  concatstd      2        1   15.947
# 13         TF (4) - attn  transformer       attn      4        1   15.998
# 14        CNN (2) - mean          cnn       mean      2        1   16.021
# 15         CNN (1) - max          cnn        max      1        1   16.061
# 16       TF (1) - concat  transformer     concat      1        1   16.172
# 17   CNN (3) - concatstd          cnn  concatstd      3        1   16.280
# 18          TF (2) - max  transformer        max      2        1   16.467
# 19      CNN (1) - concat          cnn     concat      1        1   16.516
# 20         TF (2) - attn  transformer       attn      2        1   16.763
# 21    TF (3) - concatstd  transformer  concatstd      3        1   16.778
# 22    TF (2) - concatstd  transformer  concatstd      2        1   16.786
# 23        CNN (4) - mean          cnn       mean      4        1   16.853
# 24        CNN (1) - attn          cnn       attn      1        1   17.029
# 25      CNN (4) - concat          cnn     concat      4        1   17.067
# 26          TF (3) - max  transformer        max      3        1   17.312
# 27   CNN (4) - concatstd          cnn  concatstd      4        1   17.316
# 28        CNN (1) - mean          cnn       mean      1        1   17.507
# 29         TF (2) - mean  transformer       mean      2        1   17.855
# 30        CNN (3) - attn          cnn       attn      3        1   18.362
# 31         TF (3) - attn  transformer       attn      3        1   18.548
# 32        CNN (4) - attn          cnn       attn      4        1   18.617
# 33         TF (4) - mean  transformer       mean      4        1   18.886
# 34       None (0) - attn          mlp       attn      0        1   18.940
# 35         TF (1) - attn  transformer       attn      1        1   19.007
# 36       TF (4) - concat  transformer     concat      4        1   19.470
# 37          TF (4) - max  transformer        max      4        1   20.220
# 38         TF (1) - mean  transformer       mean      1        1   23.094
# 39       None (0) - mean          mlp       mean      0        1   25.159
# 40    TF (4) - concatstd  transformer  concatstd      4        1   26.419
# 41         TF (3) - mean  transformer       mean      3        1   26.600
# 42        None (0) - max          mlp        max      0        1   28.379
# 43     None (0) - concat          mlp     concat      0        1   28.950
# 44  None (0) - concatstd          mlp  concatstd      0        1   30.956
#
#     val_std  test_mae  test_std  val_ex  val_em
# 0       0.0    12.114       0.0  16.086  11.363
# 1       0.0    13.322       0.0  17.351  11.416
# 2       0.0    12.232       0.0  17.202  12.178
# 3       0.0    12.917       0.0  18.176  11.528
# 4       0.0    13.242       0.0  17.433  12.868
# 5       0.0    13.886       0.0  18.577  11.953
# 6       0.0    13.942       0.0  18.073  12.512
# 7       0.0    13.575       0.0  18.727  12.055
# 8       0.0    14.042       0.0  18.905  12.241
# 9       0.0    12.803       0.0  18.475  12.729
# 10      0.0    13.078       0.0  18.706  12.594
# 11      0.0    13.690       0.0  19.153  12.159
# 12      0.0    15.119       0.0  19.388  12.505
# 13      0.0    15.851       0.0  19.004  12.993
# 14      0.0    13.494       0.0  19.533  12.508
# 15      0.0    13.644       0.0  19.423  12.699
# 16      0.0    14.488       0.0  19.875  12.470
# 17      0.0    12.054       0.0  18.827  13.733
# 18      0.0    14.295       0.0  19.515  13.419
# 19      0.0    14.629       0.0  19.713  13.318
# 20      0.0    15.719       0.0  19.807  13.719
# 21      0.0    14.815       0.0  19.948  13.608
# 22      0.0    14.152       0.0  20.154  13.418
# 23      0.0    16.679       0.0  20.102  13.605
# 24      0.0    14.657       0.0  20.941  13.117
# 25      0.0    15.873       0.0  19.800  14.333
# 26      0.0    16.564       0.0  20.517  14.107
# 27      0.0    14.884       0.0  20.357  14.276
# 28      0.0    15.038       0.0  21.249  13.766
# 29      0.0    15.846       0.0  21.759  13.950
# 30      0.0    16.764       0.0  21.932  14.791
# 31      0.0    17.544       0.0  22.002  15.095
# 32      0.0    17.391       0.0  22.231  15.004
# 33      0.0    15.431       0.0  23.469  14.302
# 34      0.0    17.503       0.0  22.726  15.153
# 35      0.0    17.181       0.0  22.866  15.147
# 36      0.0    18.965       0.0  24.044  14.895
# 37      0.0    17.271       0.0  25.230  15.210
# 38      0.0    19.063       0.0  27.825  18.363
# 39      0.0    21.077       0.0  30.960  19.359
# 40      0.0    22.325       0.0  32.492  20.346
# 41      0.0    23.208       0.0  32.841  20.359
# 42      0.0    22.811       0.0  34.599  22.158
# 43      0.0    23.439       0.0  34.903  22.997
# 44      0.0    25.095       0.0  36.170  25.741

# %%
plot_bar(peak_orac, "nm", "Peak oracle sweep (ProstT5) - val MAE", nulls=embed_nulls("peak_oracle"))
plot_bar(peak_orac.iloc[0:5], "nm", "Peak oracle sweep (ProstT5) - top 5", nulls=embed_nulls("peak_oracle"))

# %%
plot_scatter(peak_orac, "nm", per_peak=True)

# %%
pred_vs_truth("peak_oracle", peak_orac, "trained_models/oracle_sweep")

# %%
pred_vs_truth("peak_oracle", peak_orac, "trained_models/oracle_sweep", split="te")

# %% [markdown]
# ## Brightness - 70/15/15 split (log-brightness units)

# %%
bri = load_sweep("../scalar_design/trained_models_brightness/sweep")
show_table(bri)
# Out:
# (no .pt in ../scalar_design/trained_models_brightness/sweep; read leaderboard from results.csv — null baseline & pred-vs-truth need checkpoints)
#                    label         arch       pool  depth  n_seeds  val_mae  \
# 0           TF (1) - max  transformer        max      1        1    0.526
# 1       CNN (1) - concat          cnn     concat      1        1    0.541
# 2        TF (1) - concat  transformer     concat      1        1    0.563
# 3          CNN (1) - max          cnn        max      1        1    0.563
# 4    CNN (1) - concatstd          cnn  concatstd      1        1    0.564
# 5        TF (2) - concat  transformer     concat      2        1    0.572
# 6     TF (1) - concatstd  transformer  concatstd      1        1    0.583
# 7    CNN (3) - concatstd          cnn  concatstd      3        1    0.585
# 8    CNN (2) - concatstd          cnn  concatstd      2        1    0.594
# 9          CNN (2) - max          cnn        max      2        1    0.596
# 10         CNN (3) - max          cnn        max      3        1    0.610
# 11  None (0) - concatstd          mlp  concatstd      0        1    0.618
# 12      CNN (3) - concat          cnn     concat      3        1    0.621
# 13      CNN (2) - concat          cnn     concat      2        1    0.623
# 14        CNN (3) - attn          cnn       attn      3        1    0.630
# 15       None (0) - attn          mlp       attn      0        1    0.631
# 16          TF (2) - max  transformer        max      2        1    0.634
# 17        CNN (1) - mean          cnn       mean      1        1    0.642
# 18        CNN (3) - mean          cnn       mean      3        1    0.642
# 19        CNN (2) - mean          cnn       mean      2        1    0.654
# 20       None (0) - mean          mlp       mean      0        1    0.655
# 21         TF (2) - mean  transformer       mean      2        1    0.656
# 22         TF (1) - mean  transformer       mean      1        1    0.668
# 23        CNN (2) - attn          cnn       attn      2        1    0.670
# 24     None (0) - concat          mlp     concat      0        1    0.673
# 25        None (0) - max          mlp        max      0        1    0.675
# 26        CNN (1) - attn          cnn       attn      1        1    0.678
# 27         TF (1) - attn  transformer       attn      1        1    0.689
# 28         TF (2) - attn  transformer       attn      2        1    0.703
# 29          TF (3) - max  transformer        max      3        1    0.881
# 30         TF (3) - mean  transformer       mean      3        1    0.888
# 31         TF (3) - attn  transformer       attn      3        1    0.890
# 32    TF (2) - concatstd  transformer  concatstd      2        1    0.893
# 33       TF (3) - concat  transformer     concat      3        1    0.898
# 34    TF (3) - concatstd  transformer  concatstd      3        1    0.899
#
#     val_std  test_mae  test_std
# 0       0.0     0.654       0.0
# 1       0.0     0.640       0.0
# 2       0.0     0.640       0.0
# 3       0.0     0.610       0.0
# 4       0.0     0.626       0.0
# 5       0.0     0.610       0.0
# 6       0.0     0.619       0.0
# 7       0.0     0.690       0.0
# 8       0.0     0.627       0.0
# 9       0.0     0.622       0.0
# 10      0.0     0.649       0.0
# 11      0.0     0.680       0.0
# 12      0.0     0.689       0.0
# 13      0.0     0.636       0.0
# 14      0.0     0.680       0.0
# 15      0.0     0.692       0.0
# 16      0.0     0.727       0.0
# 17      0.0     0.670       0.0
# 18      0.0     0.674       0.0
# 19      0.0     0.675       0.0
# 20      0.0     0.651       0.0
# 21      0.0     0.693       0.0
# 22      0.0     0.688       0.0
# 23      0.0     0.691       0.0
# 24      0.0     0.624       0.0
# 25      0.0     0.660       0.0
# 26      0.0     0.642       0.0
# 27      0.0     0.713       0.0
# 28      0.0     0.683       0.0
# 29      0.0     0.834       0.0
# 30      0.0     0.849       0.0
# 31      0.0     0.846       0.0
# 32      0.0     0.859       0.0
# 33      0.0     0.851       0.0
# 34      0.0     0.853       0.0

# %%
plot_bar(bri, "log-brightness", "Brightness sweep - val MAE", nulls=embed_nulls("brightness"))
# Out:
# (skipping NN null for brightness: embedding cache not built here)

# %%
plot_scatter(bri, "log-brightness", per_peak=False)

# %%
pred_vs_truth("brightness", bri, "../scalar_design/trained_models_brightness/sweep")
# Out:
# (skipping pred-vs-truth for brightness: no checkpoints in ../scalar_design/trained_models_brightness/sweep)

# %% [markdown]
# ## pKa - 70/15/15 split (pH units)

# %%
pka = load_sweep("../scalar_design/trained_models_pka/sweep")
show_table(pka)
# Out:
# (no .pt in ../scalar_design/trained_models_pka/sweep; read leaderboard from results.csv — null baseline & pred-vs-truth need checkpoints)
#                    label         arch       pool  depth  n_seeds  val_mae  \
# 0         CNN (1) - attn          cnn       attn      1        1    0.546
# 1         CNN (2) - mean          cnn       mean      2        1    0.573
# 2         CNN (2) - attn          cnn       attn      2        1    0.597
# 3       CNN (2) - concat          cnn     concat      2        1    0.599
# 4    CNN (1) - concatstd          cnn  concatstd      1        1    0.601
# 5       CNN (1) - concat          cnn     concat      1        1    0.605
# 6         CNN (1) - mean          cnn       mean      1        1    0.607
# 7        None (0) - attn          mlp       attn      0        1    0.610
# 8          CNN (1) - max          cnn        max      1        1    0.612
# 9        None (0) - mean          mlp       mean      0        1    0.613
# 10        CNN (3) - mean          cnn       mean      3        1    0.617
# 11        CNN (3) - attn          cnn       attn      3        1    0.622
# 12         CNN (2) - max          cnn        max      2        1    0.628
# 13    TF (1) - concatstd  transformer  concatstd      1        1    0.635
# 14   CNN (3) - concatstd          cnn  concatstd      3        1    0.645
# 15         CNN (3) - max          cnn        max      3        1    0.646
# 16          TF (1) - max  transformer        max      1        1    0.647
# 17         TF (1) - attn  transformer       attn      1        1    0.655
# 18   CNN (2) - concatstd          cnn  concatstd      2        1    0.663
# 19          TF (2) - max  transformer        max      2        1    0.663
# 20      CNN (3) - concat          cnn     concat      3        1    0.692
# 21  None (0) - concatstd          mlp  concatstd      0        1    0.746
# 22         TF (1) - mean  transformer       mean      1        1    0.750
# 23         TF (2) - mean  transformer       mean      2        1    0.752
# 24       TF (1) - concat  transformer     concat      1        1    0.753
# 25         TF (2) - attn  transformer       attn      2        1    0.758
# 26         TF (3) - mean  transformer       mean      3        1    0.758
# 27         TF (3) - attn  transformer       attn      3        1    0.761
# 28     None (0) - concat          mlp     concat      0        1    0.764
# 29       TF (2) - concat  transformer     concat      2        1    0.764
# 30        None (0) - max          mlp        max      0        1    0.771
# 31       TF (3) - concat  transformer     concat      3        1    0.778
# 32    TF (3) - concatstd  transformer  concatstd      3        1    0.782
# 33          TF (3) - max  transformer        max      3        1    0.783
# 34    TF (2) - concatstd  transformer  concatstd      2        1    0.790
#
#     val_std  test_mae  test_std
# 0       0.0     0.840       0.0
# 1       0.0     0.785       0.0
# 2       0.0     0.788       0.0
# 3       0.0     0.797       0.0
# 4       0.0     0.758       0.0
# 5       0.0     0.689       0.0
# 6       0.0     0.824       0.0
# 7       0.0     0.806       0.0
# 8       0.0     0.730       0.0
# 9       0.0     0.825       0.0
# 10      0.0     0.823       0.0
# 11      0.0     0.822       0.0
# 12      0.0     0.834       0.0
# 13      0.0     0.731       0.0
# 14      0.0     0.849       0.0
# 15      0.0     0.812       0.0
# 16      0.0     0.789       0.0
# 17      0.0     0.884       0.0
# 18      0.0     0.837       0.0
# 19      0.0     0.857       0.0
# 20      0.0     0.923       0.0
# 21      0.0     0.939       0.0
# 22      0.0     0.941       0.0
# 23      0.0     0.941       0.0
# 24      0.0     0.950       0.0
# 25      0.0     0.942       0.0
# 26      0.0     0.942       0.0
# 27      0.0     0.941       0.0
# 28      0.0     0.939       0.0
# 29      0.0     0.943       0.0
# 30      0.0     0.959       0.0
# 31      0.0     0.942       0.0
# 32      0.0     0.942       0.0
# 33      0.0     0.943       0.0
# 34      0.0     0.944       0.0

# %%
plot_bar(pka, "pKa (pH)", "pKa sweep - val MAE", nulls=embed_nulls("pka"))
# Out:
# (skipping NN null for pka: embedding cache not built here)

# %%
plot_scatter(pka, "pKa (pH)", per_peak=False)

# %%
pred_vs_truth("pka", pka, "../scalar_design/trained_models_pka/sweep")
# Out:
# (skipping pred-vs-truth for pka: no checkpoints in ../scalar_design/trained_models_pka/sweep)
